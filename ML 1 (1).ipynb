# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("fehu94/student-performances-data-set-cleared-of-outlier")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/fehu94/student-performances-data-set-cleared-of-outlier?dataset_version_number=1...
# 100%|██████████| 47.6k/47.6k [00:00<00:00, 34.1MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/fehu94/student-performances-data-set-cleared-of-outlier/versions/1

# %%
import json
data={
    "username": "sravya32 ",
    "key": "KGAT_d5a9162c345822f56c79d8e40868aa3a"
}
with open('kaggle.json', 'w') as file:
    json.dump(data, file)

print("kaggle.json created successfully!")
# Out:
# kaggle.json created successfully!

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
dataset_identifier = "fehu94/student-performances-data-set-cleared-of-outlier"
print(dataset_identifier)
# Out:
# fehu94/student-performances-data-set-cleared-of-outlier

# %%
# !kaggle datasets download -d fehu94/student-performances-data-set-cleared-of-outlier
# Out:
# Dataset URL: https://www.kaggle.com/datasets/fehu94/student-performances-data-set-cleared-of-outlier
# License(s): other
# Downloading student-performances-data-set-cleared-of-outlier.zip to /content
#   0% 0.00/47.6k [00:00<?, ?B/s]
# 100% 47.6k/47.6k [00:00<00:00, 170MB/s]

# %%
# !unzip student-performances-data-set-cleared-of-outlier.zip
# Out:
# Archive:  student-performances-data-set-cleared-of-outlier.zip
#   inflating: data_set_free_of_outliers.csv

# %%
import pandas as pd
df = pd.read_csv('data_set_free_of_outliers.csv')
df.head()
# Out:
#    Hours_Studied  Parental_Involvement  Access_to_Resources  \
# 0             23                     0                    2
# 1             19                     0                    1
# 2             24                     1                    1
# 3             29                     0                    1
# 4             19                     1                    1
#
#    Extracurricular_Activities  Sleep_Hours  Previous_Scores  Motivation_Level  \
# 0                           0            7               73                 0
# 1                           0            8               59                 0
# 2                           1            7               91                 1
# 3                           1            8               98                 1
# 4                           1            6               65                 1
#
#    Internet_Access  Tutoring_Sessions  Family_Income  Teacher_Quality  \
# 0                1                  0              0              1.0
# 1                1                  2              1              1.0
# 2                1                  2              1              1.0
# 3                1                  1              1              1.0
# 4                1                  3              1              2.0
#
#    School_Type  Peer_Influence  Physical_Activity  Learning_Disabilities  \
# 0            0               1                  3                      0
# 1            0               0                  4                      0
# 2            0               2                  4                      0
# 3            0               0                  4                      0
# 4            0               2                  4                      0
#
#    Parental_Education_Level  Distance_from_Home  Gender
# 0                       0.0                 0.0       0
# 1                       1.0                 1.0       1
# 2                       2.0                 0.0       0
# 3                       0.0                 1.0       0
# 4                       1.0                 0.0       1

# %%
df.shape
# Out:
# (5034, 18)

# %%
df.columns
# Out:
# Index(['Hours_Studied', 'Parental_Involvement', 'Access_to_Resources',
#        'Extracurricular_Activities', 'Sleep_Hours', 'Previous_Scores',
#        'Motivation_Level', 'Internet_Access', 'Tutoring_Sessions',
#        'Family_Income', 'Teacher_Quality', 'School_Type', 'Peer_Influence',
#        'Physical_Activity', 'Learning_Disabilities',
#        'Parental_Education_Level', 'Distance_from_Home', 'Gender'],
#       dtype='object')

# %%
df.shape
# Out:
# (5034, 18)

# %%
df.info
# Out:
# <bound method DataFrame.info of       Hours_Studied  Parental_Involvement  Access_to_Resources  \
# 0                23                     0                    2
# 1                19                     0                    1
# 2                24                     1                    1
# 3                29                     0                    1
# 4                19                     1                    1
# ...             ...                   ...                  ...
# 5029             25                     2                    1
# 5030             23                     2                    1
# 5031             20                     1                    0
# 5032             10                     2                    2
# 5033             15                     1                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                              0            7               73
# 1                              0            8               59
# 2                              1            7               91
# 3                              1            8               98
# 4                              1            6               65
# ...                          ...          ...              ...
# 5029                           0            7               76
# 5030                           0            8               81
# 5031                           1            6               65
# 5032                           1            6               91
# 5033                           1            9               94
#
#       Motivation_Level  Internet_Access  Tutoring_Sessions  Family_Income  \
# 0                    0                1                  0              0
# 1                    0                1                  2              1
# 2                    1                1                  2              1
# 3                    1                1                  1              1
# 4                    1                1                  3              1
# ...                ...              ...                ...            ...
# 5029                 1                1                  1              2
# 5030                 1                1                  3              0
# 5031                 0                1                  3              0
# 5032                 2                1                  2              0
# 5033                 1                1                  0              1
#
#       Teacher_Quality  School_Type  Peer_Influence  Physical_Activity  \
# 0                 1.0            0               1                  3
# 1                 1.0            0               0                  4
# 2                 1.0            0               2                  4
# 3                 1.0            0               0                  4
# 4                 2.0            0               2                  4
# ...               ...          ...             ...                ...
# 5029              1.0            0               1                  2
# 5030              2.0            0               1                  2
# 5031              1.0            0               0                  2
# 5032              1.0            1               1                  3
# 5033              1.0            0               1                  4
#
#       Learning_Disabilities  Parental_Education_Level  Distance_from_Home  \
# 0                         0                       0.0                 0.0
# 1                         0                       1.0                 1.0
# 2                         0                       2.0                 0.0
# 3                         0                       0.0                 1.0
# 4                         0                       1.0                 0.0
# ...                     ...                       ...                 ...
# 5029                      0                       0.0                 0.0
# 5030                      0                       0.0                 0.0
# 5031                      0                       2.0                 0.0
# 5032                      0                       0.0                 2.0
# 5033                      0                       2.0                 0.0
#
#       Gender
# 0          0
# 1          1
# 2          0
# 3          0
# 4          1
# ...      ...
# 5029       1
# 5030       1
# 5031       1
# 5032       1
# 5033       0
#
# [5034 rows x 18 columns]>

# %%
df.describe
# Out:
# <bound method NDFrame.describe of       Hours_Studied  Parental_Involvement  Access_to_Resources  \
# 0                23                     0                    2
# 1                19                     0                    1
# 2                24                     1                    1
# 3                29                     0                    1
# 4                19                     1                    1
# ...             ...                   ...                  ...
# 5029             25                     2                    1
# 5030             23                     2                    1
# 5031             20                     1                    0
# 5032             10                     2                    2
# 5033             15                     1                    0
#
#       Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# 0                              0            7               73
# 1                              0            8               59
# 2                              1            7               91
# 3                              1            8               98
# 4                              1            6               65
# ...                          ...          ...              ...
# 5029                           0            7               76
# 5030                           0            8               81
# 5031                           1            6               65
# 5032                           1            6               91
# 5033                           1            9               94
#
#       Motivation_Level  Internet_Access  Tutoring_Sessions  Family_Income  \
# 0                    0                1                  0              0
# 1                    0                1                  2              1
# 2                    1                1                  2              1
# 3                    1                1                  1              1
# 4                    1                1                  3              1
# ...                ...              ...                ...            ...
# 5029                 1                1                  1              2
# 5030                 1                1                  3              0
# 5031                 0                1                  3              0
# 5032                 2                1                  2              0
# 5033                 1                1                  0              1
#
#       Teacher_Quality  School_Type  Peer_Influence  Physical_Activity  \
# 0                 1.0            0               1                  3
# 1                 1.0            0               0                  4
# 2                 1.0            0               2                  4
# 3                 1.0            0               0                  4
# 4                 2.0            0               2                  4
# ...               ...          ...             ...                ...
# 5029              1.0            0               1                  2
# 5030              2.0            0               1                  2
# 5031              1.0            0               0                  2
# 5032              1.0            1               1                  3
# 5033              1.0            0               1                  4
#
#       Learning_Disabilities  Parental_Education_Level  Distance_from_Home  \
# 0                         0                       0.0                 0.0
# 1                         0                       1.0                 1.0
# 2                         0                       2.0                 0.0
# 3                         0                       0.0                 1.0
# 4                         0                       1.0                 0.0
# ...                     ...                       ...                 ...
# 5029                      0                       0.0                 0.0
# 5030                      0                       0.0                 0.0
# 5031                      0                       2.0                 0.0
# 5032                      0                       0.0                 2.0
# 5033                      0                       2.0                 0.0
#
#       Gender
# 0          0
# 1          1
# 2          0
# 3          0
# 4          1
# ...      ...
# 5029       1
# 5030       1
# 5031       1
# 5032       1
# 5033       0
#
# [5034 rows x 18 columns]>

# %%
df.isnull().sum()
# Out:
# Hours_Studied                 0
# Parental_Involvement          0
# Access_to_Resources           0
# Extracurricular_Activities    0
# Sleep_Hours                   0
# Previous_Scores               0
# Motivation_Level              0
# Internet_Access               0
# Tutoring_Sessions             0
# Family_Income                 0
# Teacher_Quality               0
# School_Type                   0
# Peer_Influence                0
# Physical_Activity             0
# Learning_Disabilities         0
# Parental_Education_Level      0
# Distance_from_Home            0
# Gender                        0
# dtype: int64

# %%
df['Gender'].unique()
# Out:
# array([0, 1])

# %%
df['Gender'].value_counts()
# Out:
# Gender
# 0    2926
# 1    2108
# Name: count, dtype: int64

# %%
df['Hours_Studied'].hist()
# Out:
# <Axes: >

# %%
df['Gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Gender'>

# %%
df.select_dtypes(include='object').columns
# Out:
# Index([], dtype='object')

# %%
y=df['Hours_Studied']
x=df.drop('Hours_Studied',axis=1)
x.head(),y.head()
# Out:
# (   Parental_Involvement  Access_to_Resources  Extracurricular_Activities  \
#  0                     0                    2                           0
#  1                     0                    1                           0
#  2                     1                    1                           1
#  3                     0                    1                           1
#  4                     1                    1                           1
#
#     Sleep_Hours  Previous_Scores  Motivation_Level  Internet_Access  \
#  0            7               73                 0                1
#  1            8               59                 0                1
#  2            7               91                 1                1
#  3            8               98                 1                1
#  4            6               65                 1                1
#
#     Tutoring_Sessions  Family_Income  Teacher_Quality  School_Type  \
#  0                  0              0              1.0            0
#  1                  2              1              1.0            0
#  2                  2              1              1.0            0
#  3                  1              1              1.0            0
#  4                  3              1              2.0            0
#
#     Peer_Influence  Physical_Activity  Learning_Disabilities  \
#  0               1                  3                      0
#  1               0                  4                      0
#  2               2                  4                      0
#  3               0                  4                      0
#  4               2                  4                      0
#
#     Parental_Education_Level  Distance_from_Home  Gender
#  0                       0.0                 0.0       0
#  1                       1.0                 1.0       1
#  2                       2.0                 0.0       0
#  3                       0.0                 1.0       0
#  4                       1.0                 0.0       1  ,
#  0    23
#  1    19
#  2    24
#  3    29
#  4    19
#  Name: Hours_Studied, dtype: int64)

# %%
y.head()
# Out:
# 0    23
# 1    19
# 2    24
# 3    29
# 4    19
# Name: Hours_Studied, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
x_train.shape,x_test.shape
# Out:
# ((4027, 17), (1007, 17))

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# Initialize the StandardScaler
scaler = StandardScaler()

# Fit the scaler on the training data and transform both training and testing data
x_train_scaled = scaler.fit_transform(x_train)
x_test_scaled = scaler.transform(x_test)

# Initialize and fit the Logistic Regression model
model = LogisticRegression()
model.fit(x_train_scaled, y_train)
# Out:
# LogisticRegression()

# %%
y_pred=model.predict(x_test_scaled)
from sklearn.metrics import accuracy_score
accuracy=accuracy_score(y_test,y_pred)
print("Test accuracy:",accuracy)
# Out:
# Test accuracy: 0.06355511420059583
